# %%
conda install pandas==0.24.2
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda/envs/Python3
#
#   added / updated specs:
#     - pandas==0.24.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-0.24.2              |   py36he6710b0_0         8.5 MB
#     ------------------------------------------------------------
#                                            Total:         8.5 MB
#
# The following packages will be DOWNGRADED:
#
#   pandas                               1.0.1-py36h0573a6f_0 --> 0.24.2-py36he6710b0_0
#
#
#
# Downloading and Extracting Packages
# pandas-0.24.2        | 8.5 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda upgrade --all -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install snorkel==0.9.0 -c conda-forge
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda/envs/Python3
#
#   added / updated specs:
#     - snorkel==0.9.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     cudatoolkit-10.0.130       |                0       261.2 MB
#     cudnn-7.6.5                |       cuda10.0_0       165.0 MB
#     libprotobuf-3.11.3         |       h8b12597_0         4.8 MB  conda-forge
#     ninja-1.10.0               |       hc9558a2_0         1.9 MB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     pandas-0.24.2              |   py36hb3f55d8_1        11.1 MB  conda-forge
#     protobuf-3.11.3            |   py36he1b5a44_0         696 KB  conda-forge
#     pytorch-1.1.0              |cuda100py36he554f03_0       196.2 MB
#     scikit-learn-0.21.3        |   py36hd81dba3_0         5.0 MB
#     snorkel-0.9.0              |             py_0          85 KB  conda-forge
#     tensorboardx-1.9           |             py_0          75 KB  conda-forge
#     tqdm-4.43.0                |             py_0          47 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       648.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        pkgs/main/linux-64::cudatoolkit-10.0.130-0
#   cudnn              pkgs/main/linux-64::cudnn-7.6.5-cuda10.0_0
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.11.3-h8b12597_0
#   ninja              conda-forge/linux-64::ninja-1.10.0-hc9558a2_0
#   protobuf           conda-forge/linux-64::protobuf-3.11.3-py36he1b5a44_0
#   pytorch            pkgs/main/linux-64::pytorch-1.1.0-cuda100py36he554f03_0
#   snorkel            conda-forge/noarch::snorkel-0.9.0-py_0
#   tensorboardx       conda-forge/noarch::tensorboardx-1.9-py_0
#   tqdm               conda-forge/noarch::tqdm-4.43.0-py_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates     pkgs/main::ca-certificates-2020.1.1-0 --> conda-forge::ca-certificates-2019.11.28-hecc5488_0
#   certifi                                         pkgs/main --> conda-forge
#   openssl              pkgs/main::openssl-1.1.1d-h7b6447c_4 --> conda-forge::openssl-1.1.1d-h516909a_0
#   pandas             pkgs/main::pandas-1.0.1-py36h0573a6f_0 --> conda-forge::pandas-0.24.2-py36hb3f55d8_1
#
# The following packages will be DOWNGRADED:
#
#   scikit-learn                        0.22.1-py36hd81dba3_0 --> 0.21.3-py36hd81dba3_0
#
#
#
# Downloading and Extracting Packages
# cudnn-7.6.5          | 165.0 MB  | ##################################### | 100%
# scikit-learn-0.21.3  | 5.0 MB    | ##################################### | 100%
# pytorch-1.1.0        | 196.2 MB  | ##################################### | 100%
# cudatoolkit-10.0.130 | 261.2 MB  | ##################################### | 100%
# tqdm-4.43.0          | 47 KB     | ##################################### | 100%
# protobuf-3.11.3      | 696 KB    | ##################################### | 100%
# snorkel-0.9.0        | 85 KB     | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# ninja-1.10.0         | 1.9 MB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# libprotobuf-3.11.3   | 4.8 MB    | ##################################### | 100%
# pandas-0.24.2        | 11.1 MB   | ##################################### | 100%
# tensorboardx-1.9     | 75 KB     | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge textblob
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda/envs/Python3
#
#   added / updated specs:
#     - textblob
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     textblob-0.15.3            |             py_0         595 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         595 KB
#
# The following NEW packages will be INSTALLED:
#
#   textblob           conda-forge/noarch::textblob-0.15.3-py_0
#
#
#
# Downloading and Extracting Packages
# textblob-0.15.3      | 595 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from snorkel.labeling import LFAnalysis
from snorkel.labeling import labeling_function
from snorkel.labeling import PandasLFApplier,LabelModel
from snorkel.preprocess import preprocessor
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from textblob import TextBlob
import pandas as pd
import re

# %%
## Removing punctuation
def remove_punctuation(dataframe):
    """Remove punctuation from list of tokenized words"""
    new_words = []
    for word in dataframe.review.str.lower():
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_words.append(new_word)
    return new_words

# %%
df = pd.read_csv('development_split.csv')

# %%
df.columns = ['index','review','freshness']
df = df.set_index('index')

# %%
df.head()
# Out:
#                                                    review  freshness
# index
# 41101   Vibrant, visually exciting and emotionally res...          1
# 18134                        An enjoyable campy bad film.          0
# 3215    This brave little film, a tale of an uncompreh...          1
# 222     Excellent, accurate, smart analysis of sexual ...          1
# 181403   a merger of Cold Weather's mumblenoir and LA ...          1

# %%
df['review'] = remove_punctuation(df)

# %%
df['review'] = review

# %%
pd.set_option('display.max_colwidth', -1)

# %%
df
# Out:
#                                                                                                                                                                                                                                              review  \
# index
# 41101   vibrant visually exciting and emotionally resonant
# 18134   an enjoyable campy bad film
# 3215    this brave little film a tale of an uncomprehending hero whose every step seemingly is a misstep is not unlike the best offerings of italian neorealism of the postwar years
# 222     excellent accurate smart analysis of sexual harrassment in the workplace
# 181403   a merger of cold weathers mumblenoir and la neonoir a light and lowkey affair led by a laidback amateur sleuth who despite repeated assertions about her powers of recall is remarkably slow to work out whodunnit
# 3906    this film is basically a wellmeaning fable that is filled with good intentions that never quite manage to pay off in the end
# 1563    the chemistry between the main trio is very pleasant which is what hooks you since you will empathize immediately with these kids full review in spanish
# 654     an engaging personal essay documentary about not having children complete with interviews arguments hard data and sound reasoning coming from both sides of the debate
# 428143   if nothing else the wolverine proves how charismatic jackman is because the star far more than the stunts and the illogical script is the reason to see this xmen spinoff
# 20559   a noirish thriller with experimental trimmings that holds back most of the emotions sensitive as well as otherwise that threatened to make kubricks first feature mawkish
# 12812   i think it should be considered child abuse to inflict this tripe upon children
# 1607    rattlesnake gives you what you expect but not much more there is a terrific and devastating central performance by carmen ejogo but it doesnt shock and awe like it could
# 15576   mesmerizing filmmaking
# 3950    there is plenty of heat to burn and brand from a calmer temperature of cinematic coals
# 429447   divining the bond between mothers and daughters which in his movies can be broken but never banished almodovar is renewed
# 445756   the bigscreen scooby makes the silly original cartoon seem smart and wellcrafted in comparison
# 3024    moments of hilarity remain and the picture is inventive in its adoration for the excesses of the genre and the world of vhs recording
# 183799   mitchells giddy knowingly camp direction has a sort of glitterstick diy spirit that keeps the movie aloft long after the story itself has run out of road
# 9121     a slight improvement upon its 2010 predecessor
# 265736   loving is a dogged work not a great or inspired one but it gets to you nonetheless
# 307     any attempt to explore the impact of the opioid epidemic is buried beneath clichés and contrivances in this mildly taut drama about a crimeridden family legacy
# 46516   fincher the director of seven leads you down a murky winding path of dark dank cellars and alleys in which water drips incessantly and blood and sweat flow and coalesce as if choreographed by a balanchine
# 4852    murder mystery is a lively hodgepodge
# 3678    thankfully the voice cast is packed with popstars who are great at pouring sparky attitude into their performances
# 40066    a film that adults can enjoy on their own without feeling an obligation to take along kids as a cover
# 276091   it seems greenberg can write and directly authentically compelling material its a shame the rest of the film was such a bore
# 29835   an excellent top notch gem with beautiful direction courtesy of sofia coppola
# 10645   fifty years on were still living with the aftershocks of what muddy and wolf invented and the chess brothers midwived but its in the air and not yet on the screen
# 5117     a film like this  with a large cast and a big subject  needs a clear concise vision a strong hand and margin call just doesnt have it
#
#         freshness
# index
# 41101   1
# 18134   0
# 3215    1
# 222     1
# 181403  1
# 3906    1
# 1563    1
# 654     1
# 428143  1
# 20559   1
# 12812   0
# 1607    0
# 15576   1
# 3950    0
# 429447  1
# 445756  0
# 3024    1
# 183799  1
# 9121    0
# 265736  0
# 307     0
# 3722    0
# 31256   1
# 30934   0
# 156665  1
# 105011  0
# 6718    0
# 42756   1
# 104108  0
# 211268  1
# ...    ..
# 221256  0
# 352910  1
# 2411    1
# 91877   1
# 435     0
# 596     0
# 21078   0
# 3509    1
# 2809    1
# 12028   1
# 108781  1
# 1458    0
# 471     1
# 19063   1
# 815     1
# 9730    0
# 5218    0
# 2776    1
# 1768    0
# 1904    0
# 963     1
# 43820   1
# 46516   1
# 4852    1
# 3678    0
# 40066   1
# 276091  0
# 29835   1
# 10645   0
# 5117    0
#
# [1000 rows x 2 columns]

# %%
# Select positive reviews
positive = df.loc[df.freshness ==1]
negative = df.loc[df.freshness ==0]

# %%
positive
# Out:
#                                                                                                                                                                                                                                                   review  \
# index
# 41101   vibrant visually exciting and emotionally resonant
# 3215    this brave little film a tale of an uncomprehending hero whose every step seemingly is a misstep is not unlike the best offerings of italian neorealism of the postwar years
# 222     excellent accurate smart analysis of sexual harrassment in the workplace
# 181403   a merger of cold weathers mumblenoir and la neonoir a light and lowkey affair led by a laidback amateur sleuth who despite repeated assertions about her powers of recall is remarkably slow to work out whodunnit
# 3906    this film is basically a wellmeaning fable that is filled with good intentions that never quite manage to pay off in the end
# 1563    the chemistry between the main trio is very pleasant which is what hooks you since you will empathize immediately with these kids full review in spanish
# 654     an engaging personal essay documentary about not having children complete with interviews arguments hard data and sound reasoning coming from both sides of the debate
# 428143   if nothing else the wolverine proves how charismatic jackman is because the star far more than the stunts and the illogical script is the reason to see this xmen spinoff
# 20559   a noirish thriller with experimental trimmings that holds back most of the emotions sensitive as well as otherwise that threatened to make kubricks first feature mawkish
# 15576   mesmerizing filmmaking
# 429447   divining the bond between mothers and daughters which in his movies can be broken but never banished almodovar is renewed
# 3024    moments of hilarity remain and the picture is inventive in its adoration for the excesses of the genre and the world of vhs recording
# 30092   saint laurent imagines the life of the influential french fashion designer as a series of aesthetic erotic episodes
# 2312    with disorienting camerawork set to synth and punk it would have been easy for the film to lose itself in aesthetics but it doesnt there is no film like it now and its time for all vampirelovers and horror fans to embrace bliss
# 764     marriage story breathes life into the hardships of having a parter in your life its a wonderful film that reveals intimate parts of our lives we may have trouble articulating it may be a bit uncomfortable but thats life
# 5247    the unauthorized bash brothers experience genuinely feels as though it were made especially for me it is a smart hilarious piece of work by a remarkably talented trio
# 352910   a nicely played family entertainment with perhaps more mystery than it knows what to do with
# 2411    despite the potential double product cross marketing mo super size me 2 resounds as a heartfelt followup and spurlocks best film since the original
# 91877    the plot details are ingeniously handled and structured the rhythm of the film is just right and the tone is pitch perfect
# 3509    despite its clumsy firstact emphasis on exposition and excessive length the story is important and dern deserves a nomination for almost singlehandedly saving the film with her committed and engaging performance
# 2809    a wondrous moodily selfinvolved piece of work that employs xfiles magic realism to galvanize what might have been a routine tale of suburban teen angst
# 12028   a touching humorous and enjoyable film
# 108781   the visuals the structure the use of sound and music and the simple presence of a beating heart  all come together in a whole that is truly breathtaking
# 471     even if it is presented with luminous visuals and aweinspiring special effects this is a harrowing story exposing the cracks in a familys tightknit structure
# 19063   a fervent sweetnatured tragic romance
# 815     whilst occasionally letting her film down with some editing choices that put the subjects in a box pamela littky has made a really interesting film on the openended definition of success and the evershifting approach to pursue it
# 2776    it all adds up to an offbeat unusual horror film that totally has its own identity
# 963     arriving following the backlash transgender drama girl received upon general release earlier in the year adam is a great argument for letting trans people tell their stories
# 43820   if you can grin and bear certain eyerolling situationstheres found poetry in nebraskas slow builds of respect and its deeply understated emotional climax a father and son crossing past each other as they switch places
# 46516   fincher the director of seven leads you down a murky winding path of dark dank cellars and alleys in which water drips incessantly and blood and sweat flow and coalesce as if choreographed by a balanchine
# 4852    murder mystery is a lively hodgepodge
# 40066    a film that adults can enjoy on their own without feeling an obligation to take along kids as a cover
# 29835   an excellent top notch gem with beautiful direction courtesy of sofia coppola
#
#         freshness
# index
# 41101   1
# 3215    1
# 222     1
# 181403  1
# 3906    1
# 1563    1
# 654     1
# 428143  1
# 20559   1
# 15576   1
# 429447  1
# 3024    1
# 183799  1
# 31256   1
# 156665  1
# 42756   1
# 211268  1
# 4244    1
# 312     1
# 83602   1
# 397377  1
# 38022   1
# 4968    1
# 53283   1
# 451344  1
# 217432  1
# 382961  1
# 2178    1
# 3807    1
# 5138    1
# ...    ..
# 21535   1
# 48227   1
# 1787    1
# 4643    1
# 16215   1
# 1549    1
# 402075  1
# 37671   1
# 24638   1
# 30092   1
# 2312    1
# 764     1
# 5247    1
# 352910  1
# 2411    1
# 91877   1
# 3509    1
# 2809    1
# 12028   1
# 108781  1
# 471     1
# 19063   1
# 815     1
# 2776    1
# 963     1
# 43820   1
# 46516   1
# 4852    1
# 40066   1
# 29835   1
#
# [570 rows x 2 columns]
