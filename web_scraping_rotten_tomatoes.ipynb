# %%
import requests
from bs4 import BeautifulSoup
from csv import writer

# %%
response = requests.get('http://www.rottentomatoes.com/m/onward/reviews?type=top_critics')
soup = BeautifulSoup(response.text, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-37-031225143337> in <module>
#       1 response = requests.get('http://www.rottentomatoes.com/m/onward/reviews?type=top_critics')
# ----> 2 soup = BeautifulSoup(response.text, 'xmi')
#
# /opt/anaconda/envs/Python3/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     226                     "Couldn't find a tree builder with the features you "
#     227                     "requested: %s. Do you need to install a parser library?"
# --> 228                     % ",".join(features))
#     229
#     230         # At this point either we have a TreeBuilder instance in
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: xmi. Do you need to install a parser library?

# %%
soup = BeautifulSoup(response.text, 'html.parser')

test = soup.find_all('the_review')
# reviews = []
# for i in test:
#     j = str(i.contents[1])
#     j = j.replace("<p>\n                    \n                        ","")
#     j = j.replace("\n                    \n                </p>","")
#     reviews = reviews + [j]

# %%
test
# Out:
# []

# %%
# Out:
# []

# %%
for i in reviews:
    print(i+"\n")

# %%
test[0].contents[3]
# Out:
# <div class="pull-right smaller">
#
#                         March 3, 2020
#
#
#                         | Rating: 3/5
#
#
#                         | <a href="https://www.rollingstone.com/movies/movie-reviews/onward-movie-review-pixar-960479/" target="_blank">Full Review…</a>
# </div>

# %%
for i in test:
    j = str(i.contents[3])
    print(j)
# Out:
# <div class="pull-right smaller">
#
#                         March 3, 2020
#
#
#                         | Rating: 3/5
#
#
#                         | <a href="https://www.rollingstone.com/movies/movie-reviews/onward-movie-review-pixar-960479/" target="_blank">Full Review…</a>
# </div>
# <div class="pull-right smaller">
#
#                         March 3, 2020
#
#
#                         | Rating: 2/5
#
#
#                         | <a href="https://lwlies.com/reviews/onward/" target="_blank">Full Review…</a>
# </div>
# <div class="pull-right smaller">
#
#                         March 2, 2020
#
#
#                         | Rating: 2/4
#
#
#                         | <a href="https://www.seattletimes.com/entertainment/movies/onward-review-has-pixar-lost-its-mojo-for-a-tale-about-magic-it-has-very-little/?utm_source=RSS&amp;utm_medium=Referral&amp;utm_campaign=RSS_movies" target="_blank">Full Review…</a>
# </div>
# <div class="pull-right smaller">
#
# ...

# %%
response2 = requests.get('https://www.rottentomatoes.com/m/onward/reviews?type=top_critics')
soup = BeautifulSoup(response2.text, 'html.parser')

test = soup.find("class_=col-xs-11 subnav")

# %%
soup.body
# Out:
# <body class="body no-touch">
# <div id="emptyPlaceholder"></div>
# <script>
#                     !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function()
#                     {n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)}
#                     ;if(!f._fbq)f._fbq=n;
#                         n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#                         t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#                             document,'script','https://connect.facebook.net/en_US/fbevents.js');
#                     fbq('init', '1147905821962466');
#                     fbq('track', 'PageView');
#                 </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=1147905821962466&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# ...

# %%
soup.find(class_='item')
# Out:
# <div class="item">
# <a class="homeTab unstyled navLink fullLink" href="/">
#                             Home
#                         </a>
# </div>
